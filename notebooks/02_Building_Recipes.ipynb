# %% [markdown]
# # Chapter 2: Building Recipes
#
# **Data-Juicer User Guide**
#
# - Git Commit: `v1.4.6`
# - Commit Date: 2026-02-02
# - Repository: https://github.com/datajuicer/data-juicer

# %% [markdown]
# # Table of Contents
#
# 1. [Recipe Structure](#recipe-structure)
# 2. [Basic Recipe Example](#basic-recipe-example)
# 3. [Build Method](#build-method)
# 4. [Overriding Parameters via CLI](#overriding-parameters-via-cli)
#    - [Configuration Hierarchy](#configuration-hierarchy)
# 5. [Compare Results](#compare-results)
# 6. [Advanced Dataset Configuration](#advanced-dataset-configuration)
# 7. [Using Pre-defined Recipes](#using-pre-defined-recipes)
#    - [Recipe Categories](#recipe-categories)
#    - [Getting Started with Recipes](#getting-started-with-recipes)
#    - [Example: Refining Alpaca-CoT Dataset](#example-refining-alpaca-cot-dataset)
#    - [Exploring More Recipes](#exploring-more-recipes)
# 8. [Further Reading](#further-reading)

# %%
# Install Data-Juicer (if not installed)
# If running in Google Colab, use 'pip install' instead of 'uv pip install'
# !uv pip install py-data-juicer

# %% [markdown]
# ## Recipe Structure
#
# A Data-Juicer recipe is a YAML configuration file with three main sections:
#
# 1. **Global Parameters**: Project settings, paths, parallelism
# 2. **Process Pipeline**: Ordered list of operators
# 3. **Operator Parameters**: Configuration for each operator

# %% [markdown]
# Data-Juicer can handle various data formats (JSONL, CSV, Parquet, etc.) and loading methods (local files, S3, Hugging Face datasets, etc.), and automatically convert them to the unified format for processing. For detailed format specifications and supported data sources, please refer to **[./03_Data_Formats_and_Loading.ipynb](./03_Data_Formats_and_Loading.ipynb)**.
#
# Below we create a simple example for demonstration.

# %%
import json
import os

# Create sample data
os.makedirs('./data', exist_ok=True)

samples = [
    {"text": "This is a high-quality English text sample."},
    {"text": "Short"},
    {"text": "Another good example with sufficient length and quality."},
    {"text": "Bonjour! Ceci est un texte en français."},
    {"text": "Data processing is essential for machine learning projects."}
]

with open('./data/recipe_demo.jsonl', 'w') as f:
    for sample in samples:
        f.write(json.dumps(sample) + '\n')

print("Sample data created")
# Out:
# Sample data created

# %% [markdown]
# ## Basic Recipe Example
#
# In this recipe, we can find that it is primarily composed of two parts:
# - Global arguments
# - Operator list
#
# ### Global Arguments
#
# Global arguments typically include a set of required arguments as well as various optional arguments for optimization and debugging purposes.
#
# For all available parameters and detailed usage, please refer to [`config_all.yaml`](https://github.com/datajuicer/data-juicer/blob/main/data_juicer/config/config_all.yaml)
#
# ### Operator list
#
# Data-Juicer offers an extensive array of operators for data manipulation, encompassing modification, cleansing, filtering, and deduplication tasks.
#
# Data recipe must include the necessary operators and their respective arguments for efficient dataset processing. And Data-Juicer will process the operators sequentially as arranged in the provided operation list.

# %%
basic_recipe = """
# Global Parameters
project_name: 'recipe_demo'
dataset_path: './data/recipe_demo.jsonl'
export_path: './outputs/recipe_demo.jsonl'
np: 2  # Number of parallel processes

# Process Pipeline
process:
  # Step 1: Normalize whitespace
  - whitespace_normalization_mapper: {}
  
  # Step 2: Filter by language
  - language_id_score_filter:
      lang: 'en'
      min_score: 0.8
  
  # Step 3: Filter by text length
  - text_length_filter:
      min_len: 20
      max_len: 500
  
  # Step 4: Remove duplicates
  - document_deduplicator:
      lowercase: true
"""

os.makedirs('./configs', exist_ok=True)
with open('./configs/basic_recipe.yaml', 'w') as f:
    f.write(basic_recipe)

print("Basic recipe created")
# Out:
# Basic recipe created

# %%
# Run with default config
# !dj-process --config ./configs/basic_recipe.yaml
# Out:
# 2026-02-12 09:23:30.371 | INFO     | data_juicer.config.config:695 - dataset_path config is set and a valid local path
# 2026-02-12 09:23:30.436 | INFO     | data_juicer.config.config:1012 - Back up the input config file [/workspaces/data-juicer-hub/configs/basic_recipe.yaml] into the work_dir [/workspaces/data-juicer-hub/outputs]
# 2026-02-12 09:23:30.443 | INFO     | data_juicer.config.config:1033 - Configuration table:
# ╒══════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════╕
# │ key                      │ values                                                                                     │
# ╞══════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════╡
# │ config                   │ [Path_fr(./configs/basic_recipe.yaml, cwd=/workspaces/data-juicer-hub)]                    │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto                     │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto_num                 │ 1000                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ hpo_config               │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_algo          │ 'uniform'                                                                                  │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_ratio         │ 1.0                                                                                        │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ project_name             │ 'recipe_demo'                                                                              │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ executor_type            │ 'default'                                                                                  │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dataset_path             │ '/workspaces/data-juicer-hub/data/recipe_demo.jsonl'                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dataset                  │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ generated_dataset_config │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ validators               │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ work_dir                 │ '/workspaces/data-juicer-hub/outputs'                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_path              │ '/workspaces/data-juicer-hub/outputs/recipe_demo.jsonl'                                    │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_type              │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_shard_size        │ 0                                                                                          │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_in_parallel       │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_extra_args        │ {}                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_aws_credentials   │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ keep_stats_in_res_ds     │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ keep_hashes_in_res_ds    │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ np                       │ 2                                                                                          │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ text_keys                │ 'text'                                                                                     │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_key                │ 'images'                                                                                   │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_bytes_key          │ 'image_bytes'                                                                              │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_special_token      │ '<__dj__image>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ audio_key                │ 'audios'                                                                                   │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ audio_special_token      │ '<__dj__audio>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ video_key                │ 'videos'                                                                                   │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ video_special_token      │ '<__dj__video>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ eoc_special_token        │ '<|__dj__eoc|>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ suffixes                 │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ turbo                    │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ skip_op_error            │ True                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ use_cache                │ True                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ds_cache_dir             │ '/home/vscode/.cache/huggingface/datasets'                                                 │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ cache_compress           │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_monitor             │ True                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ use_checkpoint           │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ temp_dir                 │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_tracer              │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_trace         │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trace_num                │ 10                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trace_keys               │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_insight_mining      │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_mine          │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_fusion                │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ fusion_strategy          │ 'probe'                                                                                    │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ adaptive_batch_size      │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ process                  │ [{'whitespace_normalization_mapper': {'accelerator': None,                                 │
# │                          │                                       'audio_key': 'audios',                               │
# │                          │                                       'auto_op_parallelism': True,                         │
# │                          │                                       'batch_mode': None,                                  │
# │                          │                                       'cpu_required': None,                                │
# │                          │                                       'gpu_required': None,                                │
# │                          │                                       'history_key': 'history',                            │
# │                          │                                       'image_bytes_key': 'image_bytes',                    │
# │                          │                                       'image_key': 'images',                               │
# │                          │                                       'index_key': None,                                   │
# │                          │                                       'instruction_key': 'instruction',                    │
# │                          │                                       'mem_required': None,                                │
# │                          │                                       'memory': None,                                      │
# │                          │                                       'num_cpus': None,                                    │
# │                          │                                       'num_gpus': None,                                    │
# │                          │                                       'num_proc': 2,                                       │
# │                          │                                       'prompt_key': 'prompt',                              │
# │                          │                                       'query_key': 'query',                                │
# │                          │                                       'ray_execution_mode': None,                          │
# │                          │                                       'response_key': 'response',                          │
# │                          │                                       'runtime_env': None,                                 │
# │                          │                                       'skip_op_error': True,                               │
# │                          │                                       'system_key': 'system',                              │
# │                          │                                       'text_key': 'text',                                  │
# │                          │                                       'turbo': False,                                      │
# │                          │                                       'video_key': 'videos',                               │
# │                          │                                       'work_dir': '/workspaces/data-juicer-hub/outputs'}}, │
# │                          │  {'language_id_score_filter': {'accelerator': None,                                        │
# │                          │                                'audio_key': 'audios',                                      │
# │                          │                                'auto_op_parallelism': True,                                │
# │                          │                                'batch_mode': None,                                         │
# │                          │                                'cpu_required': None,                                       │
# │                          │                                'gpu_required': None,                                       │
# │                          │                                'history_key': 'history',                                   │
# │                          │                                'image_bytes_key': 'image_bytes',                           │
# │                          │                                'image_key': 'images',                                      │
# │                          │                                'index_key': None,                                          │
# │                          │                                'instruction_key': 'instruction',                           │
# │                          │                                'lang': 'en',                                               │
# │                          │                                'max_closed_interval': True,                                │
# │                          │                                'mem_required': None,                                       │
# │                          │                                'memory': None,                                             │
# │                          │                                'min_closed_interval': True,                                │
# │                          │                                'min_score': 0.8,                                           │
# │                          │                                'num_cpus': None,                                           │
# │                          │                                'num_gpus': None,                                           │
# │                          │                                'num_proc': 2,                                              │
# │                          │                                'prompt_key': 'prompt',                                     │
# │                          │                                'query_key': 'query',                                       │
# │                          │                                'ray_execution_mode': None,                                 │
# │                          │                                'response_key': 'response',                                 │
# │                          │                                'reversed_range': False,                                    │
# │                          │                                'runtime_env': None,                                        │
# │                          │                                'skip_op_error': True,                                      │
# │                          │                                'stats_export_path': None,                                  │
# │                          │                                'system_key': 'system',                                     │
# │                          │                                'text_key': 'text',                                         │
# │                          │                                'turbo': False,                                             │
# │                          │                                'video_key': 'videos',                                      │
# │                          │                                'work_dir': '/workspaces/data-juicer-hub/outputs'}},        │
# │                          │  {'text_length_filter': {'accelerator': None,                                              │
# │                          │                          'audio_key': 'audios',                                            │
# │                          │                          'auto_op_parallelism': True,                                      │
# │                          │                          'batch_mode': None,                                               │
# │                          │                          'cpu_required': None,                                             │
# │                          │                          'gpu_required': None,                                             │
# │                          │                          'history_key': 'history',                                         │
# │                          │                          'image_bytes_key': 'image_bytes',                                 │
# │                          │                          'image_key': 'images',                                            │
# │                          │                          'index_key': None,                                                │
# │                          │                          'instruction_key': 'instruction',                                 │
# │                          │                          'max_closed_interval': True,                                      │
# │                          │                          'max_len': 500,                                                   │
# │                          │                          'mem_required': None,                                             │
# │                          │                          'memory': None,                                                   │
# │                          │                          'min_closed_interval': True,                                      │
# │                          │                          'min_len': 20,                                                    │
# │                          │                          'num_cpus': None,                                                 │
# │                          │                          'num_gpus': None,                                                 │
# │                          │                          'num_proc': 2,                                                    │
# │                          │                          'prompt_key': 'prompt',                                           │
# │                          │                          'query_key': 'query',                                             │
# │                          │                          'ray_execution_mode': None,                                       │
# │                          │                          'response_key': 'response',                                       │
# │                          │                          'reversed_range': False,                                          │
# │                          │                          'runtime_env': None,                                              │
# │                          │                          'skip_op_error': True,                                            │
# │                          │                          'stats_export_path': None,                                        │
# │                          │                          'system_key': 'system',                                           │
# │                          │                          'text_key': 'text',                                               │
# │                          │                          'turbo': False,                                                   │
# │                          │                          'video_key': 'videos',                                            │
# │                          │                          'work_dir': '/workspaces/data-juicer-hub/outputs'}},              │
# │                          │  {'document_deduplicator': {'accelerator': None,                                           │
# │                          │                             'audio_key': 'audios',                                         │
# │                          │                             'auto_op_parallelism': True,                                   │
# │                          │                             'batch_mode': None,                                            │
# │                          │                             'cpu_required': None,                                          │
# │                          │                             'gpu_required': None,                                          │
# │                          │                             'history_key': 'history',                                      │
# │                          │                             'ignore_non_character': False,                                 │
# │                          │                             'image_bytes_key': 'image_bytes',                              │
# │                          │                             'image_key': 'images',                                         │
# │                          │                             'index_key': None,                                             │
# │                          │                             'instruction_key': 'instruction',                              │
# │                          │                             'lowercase': True,                                             │
# │                          │                             'mem_required': None,                                          │
# │                          │                             'memory': None,                                                │
# │                          │                             'num_cpus': None,                                              │
# │                          │                             'num_gpus': None,                                              │
# │                          │                             'num_proc': 2,                                                 │
# │                          │                             'prompt_key': 'prompt',                                        │
# │                          │                             'query_key': 'query',                                          │
# │                          │                             'ray_execution_mode': None,                                    │
# │                          │                             'response_key': 'response',                                    │
# │                          │                             'runtime_env': None,                                           │
# │                          │                             'skip_op_error': True,                                         │
# │                          │                             'system_key': 'system',                                        │
# │                          │                             'text_key': 'text',                                            │
# │                          │                             'turbo': False,                                                │
# │                          │                             'video_key': 'videos',                                         │
# │                          │                             'work_dir': '/workspaces/data-juicer-hub/outputs'}}]           │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ percentiles              │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_original_dataset  │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ save_stats_in_one_file   │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ray_address              │ 'auto'                                                                                     │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ custom_operator_paths    │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ debug                    │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto_op_parallelism      │ True                                                                                       │
# ╘══════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════╛
# 2026-02-12 09:23:30.445 | INFO     | data_juicer.tools.process_data:15 - Loading configuration took 0.44 seconds
# 2026-02-12 09:23:30.446 | WARNING  | data_juicer.utils.resource_utils:44 - Command nvidia-smi is not found. There might be no GPUs on this machine.
# 2026-02-12 09:23:30.448 | INFO     | data_juicer.core.executor.default_executor:54 - Using cache compression method: [None]
# 2026-02-12 09:23:30.448 | INFO     | data_juicer.core.executor.default_executor:58 - Setting up dataset builder...
# 2026-02-12 09:23:30.448 | INFO     | data_juicer.core.data.dataset_builder:48 - found dataset_path setting: /workspaces/data-juicer-hub/data/recipe_demo.jsonl
# 2026-02-12 09:23:30.448 | INFO     | data_juicer.core.data.load_strategy:84 - Getting strategy class for exec: default, data_type: local, data_source: None
# 2026-02-12 09:23:30.448 | INFO     | data_juicer.core.executor.default_executor:74 - Preparing exporter...
# 2026-02-12 09:23:30.449 | INFO     | data_juicer.tools.process_data:15 - Initializing executor took 0.00 seconds
# 2026-02-12 09:23:30.449 | INFO     | data_juicer.core.executor.default_executor:147 - Loading dataset from dataset builder...
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/json/json.py "HTTP/1.1 200 OK"
# Setting num_proc from 2 back to 1 for the jsonl split to disable multiprocessing as it only contains one shard.
# WARNING:datasets.builder:Setting num_proc from 2 back to 1 for the jsonl split to disable multiprocessing as it only contains one shard.
# Generating jsonl split: 5 examples [00:00, 3074.55 examples/s]
# 2026-02-12 09:23:30.683 | INFO     | data_juicer.format.formatter:174 - Unifying the input dataset formats...
# 2026-02-12 09:23:30.683 | INFO     | data_juicer.format.formatter:191 - There are 5 sample(s) in the original dataset.
# Filter (num_proc=2): 100%|##########| 5/5 [00:00<00:00, 25.89 examples/s]
# 2026-02-12 09:23:30.886 | INFO     | data_juicer.format.formatter:203 - 5 samples left after filtering empty text.
# 2026-02-12 09:23:30.888 | INFO     | data_juicer.core.executor.default_executor:153 - Preparing process operators...
# 2026-02-12 09:23:30.888 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# 2026-02-12 09:23:30.982 | INFO     | data_juicer.core.executor.default_executor:180 - Processing data...
# 2026-02-12 09:23:31.023 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[whitespace_normalization_mapper] based on the required memory: NoneGB and required cpu: 1.
# whitespace_normalization_mapper_process (num_proc=2): 100%|##########| 5/5 [00:00<00:00, 26.35 examples/s]
# 2026-02-12 09:23:31.573 | INFO     | data_juicer.core.data.dj_dataset:310 - [1/4] OP [whitespace_normalization_mapper] Done in 0.591s. Left 5 samples.
# 2026-02-12 09:23:31.614 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[language_id_score_filter] based on the required memory: NoneGB and required cpu: 1.
# Adding new column for stats (num_proc=2): 100%|##########| 5/5 [00:00<00:00, 29.34 examples/s]
# 2026-02-12 09:23:31.798 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[language_id_score_filter] based on the required memory: NoneGB and required cpu: 1.
# language_id_score_filter_compute_stats (num_proc=2):   0%|          | 0/5 [00:00<?, ? examples/s]2026-02-12 09:23:31.881 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# 2026-02-12 09:23:31.886 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# language_id_score_filter_compute_stats (num_proc=2): 100%|##########| 5/5 [00:00<00:00, 15.08 examples/s]
# 2026-02-12 09:23:32.144 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[language_id_score_filter] based on the required memory: NoneGB and required cpu: 1.
# language_id_score_filter_process (num_proc=2): 100%|##########| 5/5 [00:00<00:00, 27.70 examples/s]
# 2026-02-12 09:23:32.666 | INFO     | data_juicer.core.data.dj_dataset:310 - [2/4] OP [language_id_score_filter] Done in 1.092s. Left 4 samples.
# 2026-02-12 09:23:32.708 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# text_length_filter_compute_stats (num_proc=2): 100%|##########| 4/4 [00:00<00:00, 20.25 examples/s]
# 2026-02-12 09:23:32.932 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# text_length_filter_process (num_proc=2): 100%|##########| 4/4 [00:00<00:00, 20.19 examples/s]
# 2026-02-12 09:23:33.258 | INFO     | data_juicer.core.data.dj_dataset:310 - [3/4] OP [text_length_filter] Done in 0.591s. Left 3 samples.
# 2026-02-12 09:23:33.299 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[document_deduplicator] based on the required memory: NoneGB and required cpu: 1.
# document_deduplicator_compute_hash (num_proc=2): 100%|##########| 3/3 [00:00<00:00, 14.86 examples/s]
# Filter: 100%|##########| 3/3 [00:00<00:00, 439.98 examples/s]
# 2026-02-12 09:23:33.849 | INFO     | data_juicer.core.data.dj_dataset:310 - [4/4] OP [document_deduplicator] Done in 0.590s. Left 3 samples.
# 2026-02-12 09:23:36.899 | INFO     | data_juicer.utils.logger_utils:258 - Processing finished with:
# Warnings: 1
# Errors: 0
#
# Error/Warning details can be found in the log file [/workspaces/data-juicer-hub/outputs/log/export_recipe_demo.jsonl_time_20260212092330.txt] and its related log files.
# 2026-02-12 09:23:36.900 | INFO     | data_juicer.core.executor.default_executor:192 - All OPs are done in 5.918s.
# 2026-02-12 09:23:36.900 | INFO     | data_juicer.core.executor.default_executor:196 - Exporting dataset to disk...
# 2026-02-12 09:23:36.900 | INFO     | data_juicer.core.exporter:154 - Exporting computed stats into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 660.31ba/s]
# 2026-02-12 09:23:36.909 | INFO     | data_juicer.core.exporter:190 - Export dataset into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 988.99ba/s]
# 2026-02-12 09:23:36.912 | INFO     | data_juicer.tools.process_data:15 - Running executor took 6.46 seconds

# %% [markdown]
# ## Build Method
# There are two approaches to constructing a data recipe.
#
# - ### Customize the Default Configuration File
#
# The [`config_all.yaml`](https://github.com/datajuicer/data-juicer/blob/main/data_juicer/config/config_all.yaml) contains all operators and their default arguments.
#
# You just need to **remove** ops that you won't use and refine some arguments of ops.
#
# - ### Create a New Configuration from Scratch
#
# You can refer our example config file [`config_all.yaml`](https://github.com/datajuicer/data-juicer/blob/main/data_juicer/config/config_all.yaml), [op documents](https://datajuicer.github.io/data-juicer/en/main/docs/Operators.html), and advanced [Build-Up Guide for developers](https://datajuicer.github.io/data-juicer/en/main/docs/DeveloperGuide.html#build-your-own-data-recipes-and-configs).

# %% [markdown]
# ## Overriding Parameters via CLI

# %%
# Override parameters via CLI
# !dj-process --config ./configs/basic_recipe.yaml \
    --dataset_path ./data/recipe_demo.jsonl \
    --export_path ./outputs/cli_override.jsonl \
    --np 4
# Out:
# 2026-02-12 09:23:44.293 | INFO     | data_juicer.config.config:695 - dataset_path config is set and a valid local path
# 2026-02-12 09:23:44.354 | INFO     | data_juicer.config.config:1012 - Back up the input config file [/workspaces/data-juicer-hub/configs/basic_recipe.yaml] into the work_dir [/workspaces/data-juicer-hub/outputs]
# 2026-02-12 09:23:44.360 | INFO     | data_juicer.config.config:1033 - Configuration table:
# ╒══════════════════════════╤════════════════════════════════════════════════════════════════════════════════════════════╕
# │ key                      │ values                                                                                     │
# ╞══════════════════════════╪════════════════════════════════════════════════════════════════════════════════════════════╡
# │ config                   │ [Path_fr(./configs/basic_recipe.yaml, cwd=/workspaces/data-juicer-hub)]                    │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto                     │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto_num                 │ 1000                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ hpo_config               │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_algo          │ 'uniform'                                                                                  │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_ratio         │ 1.0                                                                                        │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ project_name             │ 'recipe_demo'                                                                              │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ executor_type            │ 'default'                                                                                  │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dataset_path             │ '/workspaces/data-juicer-hub/data/recipe_demo.jsonl'                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ dataset                  │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ generated_dataset_config │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ validators               │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ work_dir                 │ '/workspaces/data-juicer-hub/outputs'                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_path              │ '/workspaces/data-juicer-hub/outputs/cli_override.jsonl'                                   │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_type              │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_shard_size        │ 0                                                                                          │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_in_parallel       │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_extra_args        │ {}                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_aws_credentials   │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ keep_stats_in_res_ds     │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ keep_hashes_in_res_ds    │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ np                       │ 4                                                                                          │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ text_keys                │ 'text'                                                                                     │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_key                │ 'images'                                                                                   │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_bytes_key          │ 'image_bytes'                                                                              │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ image_special_token      │ '<__dj__image>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ audio_key                │ 'audios'                                                                                   │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ audio_special_token      │ '<__dj__audio>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ video_key                │ 'videos'                                                                                   │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ video_special_token      │ '<__dj__video>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ eoc_special_token        │ '<|__dj__eoc|>'                                                                            │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ suffixes                 │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ turbo                    │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ skip_op_error            │ True                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ use_cache                │ True                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ds_cache_dir             │ '/home/vscode/.cache/huggingface/datasets'                                                 │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ cache_compress           │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_monitor             │ True                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ use_checkpoint           │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ temp_dir                 │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_tracer              │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_trace         │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trace_num                │ 10                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trace_keys               │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ open_insight_mining      │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_mine          │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ op_fusion                │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ fusion_strategy          │ 'probe'                                                                                    │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ adaptive_batch_size      │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ process                  │ [{'whitespace_normalization_mapper': {'accelerator': None,                                 │
# │                          │                                       'audio_key': 'audios',                               │
# │                          │                                       'auto_op_parallelism': True,                         │
# │                          │                                       'batch_mode': None,                                  │
# │                          │                                       'cpu_required': None,                                │
# │                          │                                       'gpu_required': None,                                │
# │                          │                                       'history_key': 'history',                            │
# │                          │                                       'image_bytes_key': 'image_bytes',                    │
# │                          │                                       'image_key': 'images',                               │
# │                          │                                       'index_key': None,                                   │
# │                          │                                       'instruction_key': 'instruction',                    │
# │                          │                                       'mem_required': None,                                │
# │                          │                                       'memory': None,                                      │
# │                          │                                       'num_cpus': None,                                    │
# │                          │                                       'num_gpus': None,                                    │
# │                          │                                       'num_proc': 4,                                       │
# │                          │                                       'prompt_key': 'prompt',                              │
# │                          │                                       'query_key': 'query',                                │
# │                          │                                       'ray_execution_mode': None,                          │
# │                          │                                       'response_key': 'response',                          │
# │                          │                                       'runtime_env': None,                                 │
# │                          │                                       'skip_op_error': True,                               │
# │                          │                                       'system_key': 'system',                              │
# │                          │                                       'text_key': 'text',                                  │
# │                          │                                       'turbo': False,                                      │
# │                          │                                       'video_key': 'videos',                               │
# │                          │                                       'work_dir': '/workspaces/data-juicer-hub/outputs'}}, │
# │                          │  {'language_id_score_filter': {'accelerator': None,                                        │
# │                          │                                'audio_key': 'audios',                                      │
# │                          │                                'auto_op_parallelism': True,                                │
# │                          │                                'batch_mode': None,                                         │
# │                          │                                'cpu_required': None,                                       │
# │                          │                                'gpu_required': None,                                       │
# │                          │                                'history_key': 'history',                                   │
# │                          │                                'image_bytes_key': 'image_bytes',                           │
# │                          │                                'image_key': 'images',                                      │
# │                          │                                'index_key': None,                                          │
# │                          │                                'instruction_key': 'instruction',                           │
# │                          │                                'lang': 'en',                                               │
# │                          │                                'max_closed_interval': True,                                │
# │                          │                                'mem_required': None,                                       │
# │                          │                                'memory': None,                                             │
# │                          │                                'min_closed_interval': True,                                │
# │                          │                                'min_score': 0.8,                                           │
# │                          │                                'num_cpus': None,                                           │
# │                          │                                'num_gpus': None,                                           │
# │                          │                                'num_proc': 4,                                              │
# │                          │                                'prompt_key': 'prompt',                                     │
# │                          │                                'query_key': 'query',                                       │
# │                          │                                'ray_execution_mode': None,                                 │
# │                          │                                'response_key': 'response',                                 │
# │                          │                                'reversed_range': False,                                    │
# │                          │                                'runtime_env': None,                                        │
# │                          │                                'skip_op_error': True,                                      │
# │                          │                                'stats_export_path': None,                                  │
# │                          │                                'system_key': 'system',                                     │
# │                          │                                'text_key': 'text',                                         │
# │                          │                                'turbo': False,                                             │
# │                          │                                'video_key': 'videos',                                      │
# │                          │                                'work_dir': '/workspaces/data-juicer-hub/outputs'}},        │
# │                          │  {'text_length_filter': {'accelerator': None,                                              │
# │                          │                          'audio_key': 'audios',                                            │
# │                          │                          'auto_op_parallelism': True,                                      │
# │                          │                          'batch_mode': None,                                               │
# │                          │                          'cpu_required': None,                                             │
# │                          │                          'gpu_required': None,                                             │
# │                          │                          'history_key': 'history',                                         │
# │                          │                          'image_bytes_key': 'image_bytes',                                 │
# │                          │                          'image_key': 'images',                                            │
# │                          │                          'index_key': None,                                                │
# │                          │                          'instruction_key': 'instruction',                                 │
# │                          │                          'max_closed_interval': True,                                      │
# │                          │                          'max_len': 500,                                                   │
# │                          │                          'mem_required': None,                                             │
# │                          │                          'memory': None,                                                   │
# │                          │                          'min_closed_interval': True,                                      │
# │                          │                          'min_len': 20,                                                    │
# │                          │                          'num_cpus': None,                                                 │
# │                          │                          'num_gpus': None,                                                 │
# │                          │                          'num_proc': 4,                                                    │
# │                          │                          'prompt_key': 'prompt',                                           │
# │                          │                          'query_key': 'query',                                             │
# │                          │                          'ray_execution_mode': None,                                       │
# │                          │                          'response_key': 'response',                                       │
# │                          │                          'reversed_range': False,                                          │
# │                          │                          'runtime_env': None,                                              │
# │                          │                          'skip_op_error': True,                                            │
# │                          │                          'stats_export_path': None,                                        │
# │                          │                          'system_key': 'system',                                           │
# │                          │                          'text_key': 'text',                                               │
# │                          │                          'turbo': False,                                                   │
# │                          │                          'video_key': 'videos',                                            │
# │                          │                          'work_dir': '/workspaces/data-juicer-hub/outputs'}},              │
# │                          │  {'document_deduplicator': {'accelerator': None,                                           │
# │                          │                             'audio_key': 'audios',                                         │
# │                          │                             'auto_op_parallelism': True,                                   │
# │                          │                             'batch_mode': None,                                            │
# │                          │                             'cpu_required': None,                                          │
# │                          │                             'gpu_required': None,                                          │
# │                          │                             'history_key': 'history',                                      │
# │                          │                             'ignore_non_character': False,                                 │
# │                          │                             'image_bytes_key': 'image_bytes',                              │
# │                          │                             'image_key': 'images',                                         │
# │                          │                             'index_key': None,                                             │
# │                          │                             'instruction_key': 'instruction',                              │
# │                          │                             'lowercase': True,                                             │
# │                          │                             'mem_required': None,                                          │
# │                          │                             'memory': None,                                                │
# │                          │                             'num_cpus': None,                                              │
# │                          │                             'num_gpus': None,                                              │
# │                          │                             'num_proc': 4,                                                 │
# │                          │                             'prompt_key': 'prompt',                                        │
# │                          │                             'query_key': 'query',                                          │
# │                          │                             'ray_execution_mode': None,                                    │
# │                          │                             'response_key': 'response',                                    │
# │                          │                             'runtime_env': None,                                           │
# │                          │                             'skip_op_error': True,                                         │
# │                          │                             'system_key': 'system',                                        │
# │                          │                             'text_key': 'text',                                            │
# │                          │                             'turbo': False,                                                │
# │                          │                             'video_key': 'videos',                                         │
# │                          │                             'work_dir': '/workspaces/data-juicer-hub/outputs'}}]           │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ percentiles              │ []                                                                                         │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ export_original_dataset  │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ save_stats_in_one_file   │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ray_address              │ 'auto'                                                                                     │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ custom_operator_paths    │ None                                                                                       │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ debug                    │ False                                                                                      │
# ├──────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │ auto_op_parallelism      │ True                                                                                       │
# ╘══════════════════════════╧════════════════════════════════════════════════════════════════════════════════════════════╛
# 2026-02-12 09:23:44.362 | INFO     | data_juicer.tools.process_data:15 - Loading configuration took 0.40 seconds
# 2026-02-12 09:23:44.363 | WARNING  | data_juicer.utils.resource_utils:44 - Command nvidia-smi is not found. There might be no GPUs on this machine.
# 2026-02-12 09:23:44.364 | INFO     | data_juicer.core.executor.default_executor:54 - Using cache compression method: [None]
# 2026-02-12 09:23:44.364 | INFO     | data_juicer.core.executor.default_executor:58 - Setting up dataset builder...
# 2026-02-12 09:23:44.365 | INFO     | data_juicer.core.data.dataset_builder:48 - found dataset_path setting: /workspaces/data-juicer-hub/data/recipe_demo.jsonl
# 2026-02-12 09:23:44.365 | INFO     | data_juicer.core.data.load_strategy:84 - Getting strategy class for exec: default, data_type: local, data_source: None
# 2026-02-12 09:23:44.365 | INFO     | data_juicer.core.executor.default_executor:74 - Preparing exporter...
# 2026-02-12 09:23:44.365 | INFO     | data_juicer.tools.process_data:15 - Initializing executor took 0.00 seconds
# 2026-02-12 09:23:44.365 | INFO     | data_juicer.core.executor.default_executor:147 - Loading dataset from dataset builder...
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/json/json.py "HTTP/1.1 200 OK"
# 2026-02-12 09:23:44.610 | INFO     | data_juicer.format.formatter:174 - Unifying the input dataset formats...
# 2026-02-12 09:23:44.610 | INFO     | data_juicer.format.formatter:191 - There are 5 sample(s) in the original dataset.
# Filter (num_proc=4): 100%|##########| 5/5 [00:00<00:00, 20.79 examples/s]
# 2026-02-12 09:23:44.863 | INFO     | data_juicer.format.formatter:203 - 5 samples left after filtering empty text.
# 2026-02-12 09:23:44.865 | INFO     | data_juicer.core.executor.default_executor:153 - Preparing process operators...
# 2026-02-12 09:23:44.865 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# 2026-02-12 09:23:44.965 | INFO     | data_juicer.core.executor.default_executor:180 - Processing data...
# 2026-02-12 09:23:45.009 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[whitespace_normalization_mapper] based on the required memory: NoneGB and required cpu: 1.
# whitespace_normalization_mapper_process (num_proc=4): 100%|##########| 5/5 [00:00<00:00, 18.14 examples/s]
# 2026-02-12 09:23:45.562 | INFO     | data_juicer.core.data.dj_dataset:310 - [1/4] OP [whitespace_normalization_mapper] Done in 0.597s. Left 5 samples.
# 2026-02-12 09:23:45.605 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[language_id_score_filter] based on the required memory: NoneGB and required cpu: 1.
# Adding new column for stats (num_proc=4): 100%|##########| 5/5 [00:00<00:00, 20.57 examples/s]
# 2026-02-12 09:23:45.865 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[language_id_score_filter] based on the required memory: NoneGB and required cpu: 1.
# language_id_score_filter_compute_stats (num_proc=4):   0%|          | 0/5 [00:00<?, ? examples/s]2026-02-12 09:23:45.986 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# 2026-02-12 09:23:45.990 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# 2026-02-12 09:23:46.005 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# 2026-02-12 09:23:46.009 | INFO     | data_juicer.utils.model_utils:502 - Loading fasttext language identification model...
# language_id_score_filter_compute_stats (num_proc=4): 100%|##########| 5/5 [00:00<00:00, 10.63 examples/s]
# 2026-02-12 09:23:46.351 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[language_id_score_filter] based on the required memory: NoneGB and required cpu: 1.
# language_id_score_filter_process (num_proc=4): 100%|##########| 5/5 [00:00<00:00, 19.73 examples/s]
# 2026-02-12 09:23:46.674 | INFO     | data_juicer.core.data.dj_dataset:310 - [2/4] OP [language_id_score_filter] Done in 1.111s. Left 4 samples.
# 2026-02-12 09:23:46.717 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# text_length_filter_compute_stats (num_proc=4): 100%|##########| 4/4 [00:00<00:00, 14.62 examples/s]
# 2026-02-12 09:23:47.020 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# text_length_filter_process (num_proc=4): 100%|##########| 4/4 [00:00<00:00, 14.55 examples/s]
# 2026-02-12 09:23:47.772 | INFO     | data_juicer.core.data.dj_dataset:310 - [3/4] OP [text_length_filter] Done in 1.097s. Left 3 samples.
# 2026-02-12 09:23:47.814 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[document_deduplicator] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# document_deduplicator_compute_hash (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 12.38 examples/s]
# Filter: 100%|##########| 3/3 [00:00<00:00, 489.74 examples/s]
# 2026-02-12 09:23:48.367 | INFO     | data_juicer.core.data.dj_dataset:310 - [4/4] OP [document_deduplicator] Done in 0.594s. Left 3 samples.
# 2026-02-12 09:23:51.455 | INFO     | data_juicer.utils.logger_utils:258 - Processing finished with:
# Warnings: 1
# Errors: 0
#
# Error/Warning details can be found in the log file [/workspaces/data-juicer-hub/outputs/log/export_cli_override.jsonl_time_20260212092344.txt] and its related log files.
# 2026-02-12 09:23:51.455 | INFO     | data_juicer.core.executor.default_executor:192 - All OPs are done in 6.490s.
# 2026-02-12 09:23:51.455 | INFO     | data_juicer.core.executor.default_executor:196 - Exporting dataset to disk...
# 2026-02-12 09:23:51.456 | INFO     | data_juicer.core.exporter:154 - Exporting computed stats into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 681.45ba/s]
# 2026-02-12 09:23:51.465 | INFO     | data_juicer.core.exporter:190 - Export dataset into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 1787.09ba/s]
# 2026-02-12 09:23:51.467 | INFO     | data_juicer.tools.process_data:15 - Running executor took 7.10 seconds

# %% [markdown]
# ### Configuration Hierarchy
#
# Parameters are resolved in this order (highest to lowest priority):
#
# 1. **CLI arguments** (e.g., `--np 4`)
# 2. **YAML config file** (e.g., `configs/recipe.yaml`)
# 3. **Default values** (defined in operator code)

# %% [markdown]
# ## Compare Results

# %%
import json

def load_jsonl(path):
    with open(path, 'r') as f:
        return [json.loads(line) for line in f]

# Load results
basic_results = load_jsonl('./outputs/recipe_demo.jsonl')
overriding_results = load_jsonl('./outputs/cli_override.jsonl')

print(f"Original samples: 5")
print(f"Basic recipe output: {len(basic_results)} samples")
print(f"Overriding parameter output: {len(overriding_results)} samples")

assert basic_results == overriding_results
# Out:
# Original samples: 5
# Basic recipe output: 3 samples
# Overriding parameter output: 3 samples

# %% [markdown]
# ## Using Pre-defined Recipes
#
# Data-Juicer provides a comprehensive [Recipe Gallery](https://datajuicer.github.io/data-juicer-hub/en/main/docs/RecipeGallery.html) in the [data-juicer-hub](https://github.com/datajuicer/data-juicer-hub) repository, containing ready-to-use configuration files for various scenarios.

# %% [markdown]
# ### Getting Started with Recipes
#
# First, clone the data-juicer-hub repository to access all recipes:

# %%
# Clone data-juicer-hub repository
# !git clone --depth 1 https://github.com/datajuicer/data-juicer-hub.git
# Out:
# Cloning into 'data-juicer-hub'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 88 (delta 34), reused 69 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (88/88), 44.89 KiB | 901.00 KiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %% [markdown]
# ### Example: Refining Alpaca-CoT Dataset
#
# The [Alpaca-CoT recipes](https://datajuicer.github.io/data-juicer-hub/en/main/docs/AlpacaCOT.html) demonstrate how to refine instruction-tuning datasets.
#
# Each recipe applies quality-focused operators to improve dataset quality.

# %%
# Example: Use Alpaca-CoT English refinement recipe
# (Assuming you have the Alpaca-CoT dataset)

# View the recipe configuration
# !cat data-juicer-hub/refined_recipes/alpaca_cot/alpaca-cot-en-refine.yaml | head -30
# Out:
# # global parameters
# project_name: 'Data-Juicer-recipes-alpaca-cot-en'
# dataset_path: '/path/to/your/dataset'  # path to your dataset directory or file
# export_path: '/path/to/your/dataset.jsonl'
#
# np: 50  # number of subprocess to process your dataset
# open_tracer: true
#
# # process schedule
# # a list of several process operators with their arguments
# process:
#   - document_deduplicator: # 104636705
#       lowercase: true
#       ignore_non_character: true
#
#   - alphanumeric_filter: # 104636381
#       tokenization: false
#       min_ratio: 0.1
#   - character_repetition_filter: # 104630030
#       rep_len: 10
#       max_ratio: 0.6
#   - flagged_words_filter: # 104576967
#       lang: en
#       tokenization: true
#       max_ratio: 0.017
#   - maximum_line_length_filter: # 104575811
#       min_len: 20
#   - text_length_filter: # 104573711
#       min_len: 30

# %%
# Run the refinement (modify dataset_path to your actual data location)
# !dj-process --config data-juicer-hub/refined_recipes/alpaca_cot/alpaca-cot-en-refine.yaml \
#     --dataset_path /path/to/your/alpaca-cot-data.jsonl \
#     --export_path ./outputs/alpaca-cot-refined.jsonl

# %% [markdown]
# ### Exploring More Recipes
#
# Browse the complete collection:
#
# - **Recipe Gallery**: https://datajuicer.github.io/data-juicer-hub/en/main/docs/RecipeGallery.html
# - **GitHub Repository**: https://github.com/datajuicer/data-juicer-hub

# %%
# Cleanup: Remove cloned repository
# !rm -rf data-juicer-hub

# %% [markdown]
# ## Further Reading
#
# - [Recipe Gallery](https://datajuicer.github.io/data-juicer/en/main/docs/RecipeGallery.html)
# - [config_all.yaml](https://github.com/datajuicer/data-juicer/blob/main/data_juicer/config/config_all.yaml)
# - [Operators Documentation](https://datajuicer.github.io/data-juicer/en/main/docs/Operators.html)
# - [Format Conversion Tools](https://datajuicer.github.io/data-juicer/en/main/tools/fmt_conversion/README.html)
