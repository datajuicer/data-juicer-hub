# %% [markdown]
# # Chapter 3: Data Formats and Loading
#
# **Data-Juicer User Guide**
#
# - Git Commit: `v1.4.6`
# - Commit Date: 2026-02-02
# - Repository: https://github.com/datajuicer/data-juicer
#
# ---
#
# This chapter answers the most common question: "Can my data be used with Data-Juicer, and how do I load it?"

# %% [markdown]
# ## Table of Contents
#
# 1. [Supported File Formats](#supported-file-formats)
# 2. [DJ Format Specification](#dj-format-specification)
# 3. [Field Mapping](#field-mapping)
# 4. [Loading Data](#loading-data)
# 5. [Format Compatibility Quick Reference](#format-compatibility-quick-reference)
# 6. [Related Tools](#related-tools)
# 7. [Further Reading](#further-reading)

# %%
# Install Data-Juicer (if not installed)
# If running in Google Colab, use 'pip install' instead of 'uv pip install'
# !uv pip install py-data-juicer

# %%
# Setup
import json
import os

os.makedirs('./data', exist_ok=True)
os.makedirs('./configs', exist_ok=True)

samples = [
    {"title": "Introduction to ML", "text": "Machine learning is a subset of AI that enables systems to learn from data."},
    {"title": "Data-Juicer 2.0: Cloud-Scale Adaptive Data Processing for and with Foundation Models", "text": "error text"},
    {"title": "Hi", "text": "This is a long text, which is longer than 20 chars."}
]

with open('./data/sample.jsonl', 'w') as f:
    for s in samples:
        f.write(json.dumps(s) + '\n')

print(f"✅ Created sample.jsonl with {len(samples)} samples")
# Out:
# ✅ Created sample.jsonl with 3 samples

# %% [markdown]
# ---
#
# ## Supported File Formats
#
# Data-Juicer natively supports multiple file formats through its formatter system:
#
# | Formatter | Supported Extensions | Description |
# |-----------|---------------------|-------------|
# | **JsonFormatter** | `.json`, `.jsonl`, `.jsonl.zst` | JSON and JSON Lines (recommended) |
# | **ParquetFormatter** | `.parquet` | Apache Parquet (efficient for large datasets) |
# | **CsvFormatter** | `.csv` | Comma-separated values |
# | **TsvFormatter** | `.tsv` | Tab-separated values |
# | **TextFormatter** | `.txt`, `.md`, `.pdf`, `.docx`, code files | Plain text and documents |
#
# ### TextFormatter: Extended Support
#
# - **Documents**: `.txt`, `.md`, `.pdf`, `.docx`, `.tex`, `.rst`
# - **Code files**: `.py`, `.java`, `.cpp`, `.js`, `.ts`, `.go`, `.rs`, `.rb`, `.php`, `.sql`, `.sh`, `.html`, `.css`, `.xml`, and more
#
# For PDF and DOCX files, Data-Juicer automatically extracts text content.

# %% [markdown]
# ### Using the YAML Way

# %%
# Process using the default 'text' field
config = """project_name: 'basic_demo'
dataset_path: './data/sample.jsonl'
export_path: './outputs/basic_processed.jsonl'

process:
  - text_length_filter:
      min_len: 15   # Filter out samples with text shorter than 15 chars
"""

with open('./configs/basic.yaml', 'w') as f:
    f.write(config)

# !dj-process --config ./configs/basic.yaml
# Out:
# 2026-02-12 09:22:18.182 | INFO     | data_juicer.config.config:695 - dataset_path config is set and a valid local path
# 2026-02-12 09:22:18.205 | INFO     | data_juicer.config.config:1012 - Back up the input config file [/workspaces/data-juicer-hub/configs/basic.yaml] into the work_dir [/workspaces/data-juicer-hub/outputs]
# 2026-02-12 09:22:18.209 | INFO     | data_juicer.config.config:1033 - Configuration table:
# ╒══════════════════════════╤═══════════════════════════════════════════════════════════════════════════════╕
# │ key                      │ values                                                                        │
# ╞══════════════════════════╪═══════════════════════════════════════════════════════════════════════════════╡
# │ config                   │ [Path_fr(./configs/basic.yaml, cwd=/workspaces/data-juicer-hub)]              │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto                     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_num                 │ 1000                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ hpo_config               │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_algo          │ 'uniform'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_ratio         │ 1.0                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ project_name             │ 'basic_demo'                                                                  │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ executor_type            │ 'default'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset_path             │ '/workspaces/data-juicer-hub/data/sample.jsonl'                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset                  │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ generated_dataset_config │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ validators               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ work_dir                 │ '/workspaces/data-juicer-hub/outputs'                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_path              │ '/workspaces/data-juicer-hub/outputs/basic_processed.jsonl'                   │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_type              │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_shard_size        │ 0                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_in_parallel       │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_extra_args        │ {}                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_aws_credentials   │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_stats_in_res_ds     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_hashes_in_res_ds    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ np                       │ 4                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ text_keys                │ 'text'                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_key                │ 'images'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_bytes_key          │ 'image_bytes'                                                                 │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_special_token      │ '<__dj__image>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_key                │ 'audios'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_special_token      │ '<__dj__audio>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_key                │ 'videos'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_special_token      │ '<__dj__video>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ eoc_special_token        │ '<|__dj__eoc|>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ suffixes                 │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ turbo                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ skip_op_error            │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_cache                │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ds_cache_dir             │ '/home/vscode/.cache/huggingface/datasets'                                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ cache_compress           │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_monitor             │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_checkpoint           │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ temp_dir                 │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_tracer              │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_trace         │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_num                │ 10                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_keys               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_insight_mining      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_mine          │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_fusion                │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ fusion_strategy          │ 'probe'                                                                       │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ adaptive_batch_size      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ process                  │ [{'text_length_filter': {'accelerator': None,                                 │
# │                          │                          'audio_key': 'audios',                               │
# │                          │                          'auto_op_parallelism': True,                         │
# │                          │                          'batch_mode': None,                                  │
# │                          │                          'cpu_required': None,                                │
# │                          │                          'gpu_required': None,                                │
# │                          │                          'history_key': 'history',                            │
# │                          │                          'image_bytes_key': 'image_bytes',                    │
# │                          │                          'image_key': 'images',                               │
# │                          │                          'index_key': None,                                   │
# │                          │                          'instruction_key': 'instruction',                    │
# │                          │                          'max_closed_interval': True,                         │
# │                          │                          'max_len': 9223372036854775807,                      │
# │                          │                          'mem_required': None,                                │
# │                          │                          'memory': None,                                      │
# │                          │                          'min_closed_interval': True,                         │
# │                          │                          'min_len': 15,                                       │
# │                          │                          'num_cpus': None,                                    │
# │                          │                          'num_gpus': None,                                    │
# │                          │                          'num_proc': 4,                                       │
# │                          │                          'prompt_key': 'prompt',                              │
# │                          │                          'query_key': 'query',                                │
# │                          │                          'ray_execution_mode': None,                          │
# │                          │                          'response_key': 'response',                          │
# │                          │                          'reversed_range': False,                             │
# │                          │                          'runtime_env': None,                                 │
# │                          │                          'skip_op_error': True,                               │
# │                          │                          'stats_export_path': None,                           │
# │                          │                          'system_key': 'system',                              │
# │                          │                          'text_key': 'text',                                  │
# │                          │                          'turbo': False,                                      │
# │                          │                          'video_key': 'videos',                               │
# │                          │                          'work_dir': '/workspaces/data-juicer-hub/outputs'}}] │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ percentiles              │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_original_dataset  │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ save_stats_in_one_file   │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ray_address              │ 'auto'                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ custom_operator_paths    │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ debug                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_op_parallelism      │ True                                                                          │
# ╘══════════════════════════╧═══════════════════════════════════════════════════════════════════════════════╛
# 2026-02-12 09:22:18.210 | INFO     | data_juicer.tools.process_data:15 - Loading configuration took 0.31 seconds
# 2026-02-12 09:22:18.212 | WARNING  | data_juicer.utils.resource_utils:44 - Command nvidia-smi is not found. There might be no GPUs on this machine.
# 2026-02-12 09:22:18.213 | INFO     | data_juicer.core.executor.default_executor:54 - Using cache compression method: [None]
# 2026-02-12 09:22:18.214 | INFO     | data_juicer.core.executor.default_executor:58 - Setting up dataset builder...
# 2026-02-12 09:22:18.214 | INFO     | data_juicer.core.data.dataset_builder:48 - found dataset_path setting: /workspaces/data-juicer-hub/data/sample.jsonl
# 2026-02-12 09:22:18.214 | INFO     | data_juicer.core.data.load_strategy:84 - Getting strategy class for exec: default, data_type: local, data_source: None
# 2026-02-12 09:22:18.214 | INFO     | data_juicer.core.executor.default_executor:74 - Preparing exporter...
# 2026-02-12 09:22:18.214 | INFO     | data_juicer.tools.process_data:15 - Initializing executor took 0.00 seconds
# 2026-02-12 09:22:18.215 | INFO     | data_juicer.core.executor.default_executor:147 - Loading dataset from dataset builder...
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/json/json.py "HTTP/1.1 200 OK"
# Setting num_proc from 4 back to 1 for the jsonl split to disable multiprocessing as it only contains one shard.
# WARNING:datasets.builder:Setting num_proc from 4 back to 1 for the jsonl split to disable multiprocessing as it only contains one shard.
# Generating jsonl split: 3 examples [00:00, 1427.12 examples/s]
# 2026-02-12 09:22:18.484 | INFO     | data_juicer.format.formatter:174 - Unifying the input dataset formats...
# 2026-02-12 09:22:18.485 | INFO     | data_juicer.format.formatter:191 - There are 3 sample(s) in the original dataset.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Filter (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 14.52 examples/s]
# 2026-02-12 09:22:18.702 | INFO     | data_juicer.format.formatter:203 - 3 samples left after filtering empty text.
# 2026-02-12 09:22:18.705 | INFO     | data_juicer.core.executor.default_executor:153 - Preparing process operators...
# 2026-02-12 09:22:18.705 | INFO     | data_juicer.core.executor.default_executor:180 - Processing data...
# 2026-02-12 09:22:18.746 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Adding new column for stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 15.49 examples/s]
# 2026-02-12 09:22:18.957 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_compute_stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 13.03 examples/s]
# 2026-02-12 09:22:19.209 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_process (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 12.99 examples/s]
# 2026-02-12 09:22:19.799 | INFO     | data_juicer.core.data.dj_dataset:310 - [1/1] OP [text_length_filter] Done in 1.094s. Left 2 samples.
# 2026-02-12 09:22:20.606 | INFO     | data_juicer.utils.logger_utils:258 - Processing finished with:
# Warnings: 1
# Errors: 0
#
# Error/Warning details can be found in the log file [/workspaces/data-juicer-hub/outputs/log/export_basic_processed.jsonl_time_20260212092218.txt] and its related log files.
# 2026-02-12 09:22:20.606 | INFO     | data_juicer.core.executor.default_executor:192 - All OPs are done in 1.901s.
# 2026-02-12 09:22:20.607 | INFO     | data_juicer.core.executor.default_executor:196 - Exporting dataset to disk...
# 2026-02-12 09:22:20.607 | INFO     | data_juicer.core.exporter:154 - Exporting computed stats into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 737.01ba/s]
# 2026-02-12 09:22:20.616 | INFO     | data_juicer.core.exporter:190 - Export dataset into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 1334.92ba/s]
# 2026-02-12 09:22:20.618 | INFO     | data_juicer.tools.process_data:15 - Running executor took 2.40 seconds

# %%
# Check results
print("Processed output (samples with text >= 15 chars):")
with open('./outputs/basic_processed.jsonl', 'r') as f:
    for line in f:
        print(json.loads(line))
# Out:
# Processed output (samples with text >= 15 chars):
# {'title': 'Introduction to ML', 'text': 'Machine learning is a subset of AI that enables systems to learn from data.'}
# {'title': 'Hi', 'text': 'This is a long text, which is longer than 20 chars.'}

# %% [markdown]
# Other formats can be loaded in the same way:
#
# ```yaml
# # JSONL (most common)
# dataset_path: './data/train.jsonl'
#
# # Parquet (efficient for large datasets)
# dataset_path: './data/train.parquet'
#
# # CSV
# dataset_path: './data/train.csv'
#
# # Specify file suffixes explicitly
# dataset_path: './data/'
# suffixes: ['.csv', '.json']  # Only load these file types
# ```
#
# For complex data loading scenarios (data mixing, sampling, remote datasets), see **[Chapter 10: Advanced Dataset Configuration](./10_Advanced_Dataset_Configuration.ipynb)**.

# %% [markdown]
# ---
#
# ## DJ Format Specification
#
# While Data-Juicer supports multiple file formats, the **data structure** follows a unified schema.
#
# ### Core Fields
#
# ```python
# {
#   "text": "xxx",           # For pretraining and general language modeling
#   "query": "xxx",          # For dialog and question-answering
#   "response": "xxx",       # For dialog responses and assistant output
# }
# ```
#
# **Note**: Different dataset types use different core fields. A dialog dataset would have `query` and `response`, while a pretraining dataset would have only `text`.
#
# ### Multimodal Fields
#
# For multimodal data, DJ Format uses **file paths** (not embedded data):
#
# ```json
# {
#   "text": "<__dj__image> Antarctica is Earth's southernmost and least-populated continent. <|__dj__eoc|> "
#           "<__dj__video> <__dj__audio> Situated almost entirely south of the Antarctic Circle and surrounded by the "
#           "Southern Ocean (also known as the Antarctic Ocean), it contains the geographic South Pole. <|__dj__eoc|> "
#           "Antarctica is the fifth-largest continent, being about 40% larger than Europe, "
#           "and has an area of 14,200,000 km2 (5,500,000 sq mi). <__dj__image> <__dj__image> <|__dj__eoc|> "
#           "Most of Antarctica is covered by the Antarctic ice sheet, "
#           "with an average thickness of 1.9 km (1.2 mi). <|__dj__eoc|>",
#   "images": [
#     "path/to/the/image/of/antarctica_snowfield",
#     "path/to/the/image/of/antarctica_map",
#     "path/to/the/image/of/europe_map"
#   ],
#   "audios": [
#     "path/to/the/audio/of/sound_of_waves_in_Antarctic_Ocean"
#   ],
#   "videos": [
#     "path/to/the/video/of/remote_sensing_view_of_antarctica"
#   ]
# }
# ```
#
# **Special Tokens** (configurable in YAML):
# - `<__dj__image>`: Image placeholder (config: `image_special_token`)
# - `<__dj__audio>`: Audio placeholder (config: `audio_special_token`)
# - `<__dj__video>`: Video placeholder (config: `video_special_token`)
# - `<|__dj__eoc|>`: End of chunk (config: `eoc_special_token`)
#
# ### Metadata Fields
#
# Optional fields for tracking data lineage (which could be primitive or produced by Data-Juicer):
#
# ```json
# {
#   "text": "Sample text...",
#   "__dj__meta__": {"source": "wikipedia", "date": "2024-01"},
#   "__dj__stats__": {"lang": "en", "text_length": 256}
# }
# ```

# %% [markdown]
# ---
#
# ## Field Mapping
#
# You don't need to rename your fields. Data-Juicer supports field mapping to work with any field names.
#
# ### Text Field Mapping (`text_keys`)
#
# If your data uses a different field name for text content:
#
# ```yaml
# # Your data: {"content": "Hello world", "id": 1}
# text_keys: 'content'   # Map 'content' as the text field
# ```

# %% [markdown]
# ### Using 'title' Field Instead of 'text'

# %%
# Process using 'title' field instead of 'text'
config = """project_name: 'field_mapping_demo'
dataset_path: './data/sample.jsonl'
export_path: './outputs/title_processed.jsonl'

# Field mapping: use 'title' as the text field
text_keys: 'title'

process:
  - text_length_filter:
      min_len: 15   # Filter out samples with title shorter than 15 chars
"""

with open('./configs/field_mapping.yaml', 'w') as f:
    f.write(config)

# !dj-process --config ./configs/field_mapping.yaml
# Out:
# 2026-02-12 09:22:27.764 | INFO     | data_juicer.config.config:695 - dataset_path config is set and a valid local path
# 2026-02-12 09:22:27.787 | INFO     | data_juicer.config.config:1012 - Back up the input config file [/workspaces/data-juicer-hub/configs/field_mapping.yaml] into the work_dir [/workspaces/data-juicer-hub/outputs]
# 2026-02-12 09:22:27.791 | INFO     | data_juicer.config.config:1033 - Configuration table:
# ╒══════════════════════════╤═══════════════════════════════════════════════════════════════════════════════╕
# │ key                      │ values                                                                        │
# ╞══════════════════════════╪═══════════════════════════════════════════════════════════════════════════════╡
# │ config                   │ [Path_fr(./configs/field_mapping.yaml, cwd=/workspaces/data-juicer-hub)]      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto                     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_num                 │ 1000                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ hpo_config               │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_algo          │ 'uniform'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_ratio         │ 1.0                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ project_name             │ 'field_mapping_demo'                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ executor_type            │ 'default'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset_path             │ '/workspaces/data-juicer-hub/data/sample.jsonl'                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset                  │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ generated_dataset_config │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ validators               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ work_dir                 │ '/workspaces/data-juicer-hub/outputs'                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_path              │ '/workspaces/data-juicer-hub/outputs/title_processed.jsonl'                   │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_type              │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_shard_size        │ 0                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_in_parallel       │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_extra_args        │ {}                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_aws_credentials   │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_stats_in_res_ds     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_hashes_in_res_ds    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ np                       │ 4                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ text_keys                │ 'title'                                                                       │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_key                │ 'images'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_bytes_key          │ 'image_bytes'                                                                 │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_special_token      │ '<__dj__image>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_key                │ 'audios'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_special_token      │ '<__dj__audio>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_key                │ 'videos'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_special_token      │ '<__dj__video>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ eoc_special_token        │ '<|__dj__eoc|>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ suffixes                 │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ turbo                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ skip_op_error            │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_cache                │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ds_cache_dir             │ '/home/vscode/.cache/huggingface/datasets'                                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ cache_compress           │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_monitor             │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_checkpoint           │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ temp_dir                 │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_tracer              │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_trace         │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_num                │ 10                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_keys               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_insight_mining      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_mine          │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_fusion                │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ fusion_strategy          │ 'probe'                                                                       │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ adaptive_batch_size      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ process                  │ [{'text_length_filter': {'accelerator': None,                                 │
# │                          │                          'audio_key': 'audios',                               │
# │                          │                          'auto_op_parallelism': True,                         │
# │                          │                          'batch_mode': None,                                  │
# │                          │                          'cpu_required': None,                                │
# │                          │                          'gpu_required': None,                                │
# │                          │                          'history_key': 'history',                            │
# │                          │                          'image_bytes_key': 'image_bytes',                    │
# │                          │                          'image_key': 'images',                               │
# │                          │                          'index_key': None,                                   │
# │                          │                          'instruction_key': 'instruction',                    │
# │                          │                          'max_closed_interval': True,                         │
# │                          │                          'max_len': 9223372036854775807,                      │
# │                          │                          'mem_required': None,                                │
# │                          │                          'memory': None,                                      │
# │                          │                          'min_closed_interval': True,                         │
# │                          │                          'min_len': 15,                                       │
# │                          │                          'num_cpus': None,                                    │
# │                          │                          'num_gpus': None,                                    │
# │                          │                          'num_proc': 4,                                       │
# │                          │                          'prompt_key': 'prompt',                              │
# │                          │                          'query_key': 'query',                                │
# │                          │                          'ray_execution_mode': None,                          │
# │                          │                          'response_key': 'response',                          │
# │                          │                          'reversed_range': False,                             │
# │                          │                          'runtime_env': None,                                 │
# │                          │                          'skip_op_error': True,                               │
# │                          │                          'stats_export_path': None,                           │
# │                          │                          'system_key': 'system',                              │
# │                          │                          'text_key': 'title',                                 │
# │                          │                          'turbo': False,                                      │
# │                          │                          'video_key': 'videos',                               │
# │                          │                          'work_dir': '/workspaces/data-juicer-hub/outputs'}}] │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ percentiles              │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_original_dataset  │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ save_stats_in_one_file   │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ray_address              │ 'auto'                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ custom_operator_paths    │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ debug                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_op_parallelism      │ True                                                                          │
# ╘══════════════════════════╧═══════════════════════════════════════════════════════════════════════════════╛
# 2026-02-12 09:22:27.792 | INFO     | data_juicer.tools.process_data:15 - Loading configuration took 0.32 seconds
# 2026-02-12 09:22:27.794 | WARNING  | data_juicer.utils.resource_utils:44 - Command nvidia-smi is not found. There might be no GPUs on this machine.
# 2026-02-12 09:22:27.795 | INFO     | data_juicer.core.executor.default_executor:54 - Using cache compression method: [None]
# 2026-02-12 09:22:27.795 | INFO     | data_juicer.core.executor.default_executor:58 - Setting up dataset builder...
# 2026-02-12 09:22:27.796 | INFO     | data_juicer.core.data.dataset_builder:48 - found dataset_path setting: /workspaces/data-juicer-hub/data/sample.jsonl
# 2026-02-12 09:22:27.796 | INFO     | data_juicer.core.data.load_strategy:84 - Getting strategy class for exec: default, data_type: local, data_source: None
# 2026-02-12 09:22:27.796 | INFO     | data_juicer.core.executor.default_executor:74 - Preparing exporter...
# 2026-02-12 09:22:27.797 | INFO     | data_juicer.tools.process_data:15 - Initializing executor took 0.00 seconds
# 2026-02-12 09:22:27.797 | INFO     | data_juicer.core.executor.default_executor:147 - Loading dataset from dataset builder...
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/json/json.py "HTTP/1.1 200 OK"
# 2026-02-12 09:22:28.021 | INFO     | data_juicer.format.formatter:174 - Unifying the input dataset formats...
# 2026-02-12 09:22:28.021 | INFO     | data_juicer.format.formatter:191 - There are 3 sample(s) in the original dataset.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Filter (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 12.47 examples/s]
# 2026-02-12 09:22:28.274 | INFO     | data_juicer.format.formatter:203 - 3 samples left after filtering empty text.
# 2026-02-12 09:22:28.276 | INFO     | data_juicer.core.executor.default_executor:153 - Preparing process operators...
# 2026-02-12 09:22:28.277 | INFO     | data_juicer.core.executor.default_executor:180 - Processing data...
# 2026-02-12 09:22:28.320 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Adding new column for stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 14.62 examples/s]
# 2026-02-12 09:22:28.542 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_compute_stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 12.89 examples/s]
# 2026-02-12 09:22:28.797 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_process (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 12.30 examples/s]
# 2026-02-12 09:22:29.376 | INFO     | data_juicer.core.data.dj_dataset:310 - [1/1] OP [text_length_filter] Done in 1.099s. Left 2 samples.
# 2026-02-12 09:22:30.174 | INFO     | data_juicer.utils.logger_utils:258 - Processing finished with:
# Warnings: 1
# Errors: 0
#
# Error/Warning details can be found in the log file [/workspaces/data-juicer-hub/outputs/log/export_title_processed.jsonl_time_20260212092227.txt] and its related log files.
# 2026-02-12 09:22:30.175 | INFO     | data_juicer.core.executor.default_executor:192 - All OPs are done in 1.898s.
# 2026-02-12 09:22:30.175 | INFO     | data_juicer.core.executor.default_executor:196 - Exporting dataset to disk...
# 2026-02-12 09:22:30.176 | INFO     | data_juicer.core.exporter:154 - Exporting computed stats into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 674.33ba/s]
# 2026-02-12 09:22:30.185 | INFO     | data_juicer.core.exporter:190 - Export dataset into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 914.39ba/s]
# 2026-02-12 09:22:30.188 | INFO     | data_juicer.tools.process_data:15 - Running executor took 2.39 seconds

# %%
# Check results
print("Processed output (samples with title >= 15 chars):")
with open('./outputs/title_processed.jsonl', 'r') as f:
    for line in f:
        print(json.loads(line))
# Out:
# Processed output (samples with title >= 15 chars):
# {'title': 'Introduction to ML', 'text': 'Machine learning is a subset of AI that enables systems to learn from data.'}
# {'title': 'Data-Juicer 2.0: Cloud-Scale Adaptive Data Processing for and with Foundation Models', 'text': 'error text'}

# %% [markdown]
# ### Multiple Text Fields
#
# When your data has **multiple text fields** that different operators need to process, declare them all in the global config:
#
# ```yaml
# # Declare ALL text fields upfront
# text_keys: ['title', 'text']
# ```
#
# **Why declare multiple `text_keys` globally?**
# - During loading, Data-Juicer validates that all declared fields exist
# - Prevents errors when operators access undeclared fields
# - If an operator doesn't specify `text_key`, it uses the **first** one in the list

# %% [markdown]
# ### Different Operators for Different Fields

# %%
# Process with different operators for different fields
config = """project_name: 'multi_field_demo'
dataset_path: './data/sample.jsonl'
export_path: './outputs/multi_field_processed.jsonl'

# Declare ALL text fields upfront
text_keys: ['title', 'text']

process:
  - text_length_filter:
      text_key: 'title'    # Process 'title' field
      min_len: 15
  
  - words_num_filter:      # Filter by total word count (>= 5)
      text_key: 'text'     # Process 'text' field  
      min_hum: 5
"""

with open('./configs/multi_field.yaml', 'w') as f:
    f.write(config)

# !dj-process --config ./configs/multi_field.yaml
# Out:
# 2026-02-12 09:22:37.316 | INFO     | data_juicer.config.config:695 - dataset_path config is set and a valid local path
# 2026-02-12 09:22:37.351 | INFO     | data_juicer.config.config:1012 - Back up the input config file [/workspaces/data-juicer-hub/configs/multi_field.yaml] into the work_dir [/workspaces/data-juicer-hub/outputs]
# 2026-02-12 09:22:37.356 | INFO     | data_juicer.config.config:1033 - Configuration table:
# ╒══════════════════════════╤═══════════════════════════════════════════════════════════════════════════════╕
# │ key                      │ values                                                                        │
# ╞══════════════════════════╪═══════════════════════════════════════════════════════════════════════════════╡
# │ config                   │ [Path_fr(./configs/multi_field.yaml, cwd=/workspaces/data-juicer-hub)]        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto                     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_num                 │ 1000                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ hpo_config               │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_algo          │ 'uniform'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_ratio         │ 1.0                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ project_name             │ 'multi_field_demo'                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ executor_type            │ 'default'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset_path             │ '/workspaces/data-juicer-hub/data/sample.jsonl'                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset                  │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ generated_dataset_config │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ validators               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ work_dir                 │ '/workspaces/data-juicer-hub/outputs'                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_path              │ '/workspaces/data-juicer-hub/outputs/multi_field_processed.jsonl'             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_type              │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_shard_size        │ 0                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_in_parallel       │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_extra_args        │ {}                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_aws_credentials   │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_stats_in_res_ds     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_hashes_in_res_ds    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ np                       │ 4                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ text_keys                │ ['title', 'text']                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_key                │ 'images'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_bytes_key          │ 'image_bytes'                                                                 │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_special_token      │ '<__dj__image>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_key                │ 'audios'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_special_token      │ '<__dj__audio>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_key                │ 'videos'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_special_token      │ '<__dj__video>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ eoc_special_token        │ '<|__dj__eoc|>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ suffixes                 │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ turbo                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ skip_op_error            │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_cache                │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ds_cache_dir             │ '/home/vscode/.cache/huggingface/datasets'                                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ cache_compress           │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_monitor             │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_checkpoint           │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ temp_dir                 │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_tracer              │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_trace         │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_num                │ 10                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_keys               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_insight_mining      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_mine          │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_fusion                │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ fusion_strategy          │ 'probe'                                                                       │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ adaptive_batch_size      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ process                  │ [{'text_length_filter': {'accelerator': None,                                 │
# │                          │                          'audio_key': 'audios',                               │
# │                          │                          'auto_op_parallelism': True,                         │
# │                          │                          'batch_mode': None,                                  │
# │                          │                          'cpu_required': None,                                │
# │                          │                          'gpu_required': None,                                │
# │                          │                          'history_key': 'history',                            │
# │                          │                          'image_bytes_key': 'image_bytes',                    │
# │                          │                          'image_key': 'images',                               │
# │                          │                          'index_key': None,                                   │
# │                          │                          'instruction_key': 'instruction',                    │
# │                          │                          'max_closed_interval': True,                         │
# │                          │                          'max_len': 9223372036854775807,                      │
# │                          │                          'mem_required': None,                                │
# │                          │                          'memory': None,                                      │
# │                          │                          'min_closed_interval': True,                         │
# │                          │                          'min_len': 15,                                       │
# │                          │                          'num_cpus': None,                                    │
# │                          │                          'num_gpus': None,                                    │
# │                          │                          'num_proc': 4,                                       │
# │                          │                          'prompt_key': 'prompt',                              │
# │                          │                          'query_key': 'query',                                │
# │                          │                          'ray_execution_mode': None,                          │
# │                          │                          'response_key': 'response',                          │
# │                          │                          'reversed_range': False,                             │
# │                          │                          'runtime_env': None,                                 │
# │                          │                          'skip_op_error': True,                               │
# │                          │                          'stats_export_path': None,                           │
# │                          │                          'system_key': 'system',                              │
# │                          │                          'text_key': 'title',                                 │
# │                          │                          'turbo': False,                                      │
# │                          │                          'video_key': 'videos',                               │
# │                          │                          'work_dir': '/workspaces/data-juicer-hub/outputs'}}, │
# │                          │  {'words_num_filter': {'accelerator': None,                                   │
# │                          │                        'audio_key': 'audios',                                 │
# │                          │                        'auto_op_parallelism': True,                           │
# │                          │                        'batch_mode': None,                                    │
# │                          │                        'cpu_required': None,                                  │
# │                          │                        'gpu_required': None,                                  │
# │                          │                        'history_key': 'history',                              │
# │                          │                        'image_bytes_key': 'image_bytes',                      │
# │                          │                        'image_key': 'images',                                 │
# │                          │                        'index_key': None,                                     │
# │                          │                        'instruction_key': 'instruction',                      │
# │                          │                        'lang': 'en',                                          │
# │                          │                        'max_closed_interval': True,                           │
# │                          │                        'max_num': 9223372036854775807,                        │
# │                          │                        'mem_required': None,                                  │
# │                          │                        'memory': None,                                        │
# │                          │                        'min_closed_interval': True,                           │
# │                          │                        'min_hum': 5,                                          │
# │                          │                        'min_num': 10,                                         │
# │                          │                        'num_cpus': None,                                      │
# │                          │                        'num_gpus': None,                                      │
# │                          │                        'num_proc': 4,                                         │
# │                          │                        'prompt_key': 'prompt',                                │
# │                          │                        'query_key': 'query',                                  │
# │                          │                        'ray_execution_mode': None,                            │
# │                          │                        'response_key': 'response',                            │
# │                          │                        'reversed_range': False,                               │
# │                          │                        'runtime_env': None,                                   │
# │                          │                        'skip_op_error': True,                                 │
# │                          │                        'stats_export_path': None,                             │
# │                          │                        'system_key': 'system',                                │
# │                          │                        'text_key': 'text',                                    │
# │                          │                        'tokenization': False,                                 │
# │                          │                        'turbo': False,                                        │
# │                          │                        'video_key': 'videos',                                 │
# │                          │                        'work_dir': '/workspaces/data-juicer-hub/outputs'}}]   │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ percentiles              │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_original_dataset  │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ save_stats_in_one_file   │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ray_address              │ 'auto'                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ custom_operator_paths    │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ debug                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_op_parallelism      │ True                                                                          │
# ╘══════════════════════════╧═══════════════════════════════════════════════════════════════════════════════╛
# 2026-02-12 09:22:37.358 | INFO     | data_juicer.tools.process_data:15 - Loading configuration took 0.33 seconds
# 2026-02-12 09:22:37.360 | WARNING  | data_juicer.utils.resource_utils:44 - Command nvidia-smi is not found. There might be no GPUs on this machine.
# 2026-02-12 09:22:37.361 | INFO     | data_juicer.core.executor.default_executor:54 - Using cache compression method: [None]
# 2026-02-12 09:22:37.361 | INFO     | data_juicer.core.executor.default_executor:58 - Setting up dataset builder...
# 2026-02-12 09:22:37.361 | INFO     | data_juicer.core.data.dataset_builder:48 - found dataset_path setting: /workspaces/data-juicer-hub/data/sample.jsonl
# 2026-02-12 09:22:37.362 | INFO     | data_juicer.core.data.load_strategy:84 - Getting strategy class for exec: default, data_type: local, data_source: None
# 2026-02-12 09:22:37.362 | INFO     | data_juicer.core.executor.default_executor:74 - Preparing exporter...
# 2026-02-12 09:22:37.362 | INFO     | data_juicer.tools.process_data:15 - Initializing executor took 0.00 seconds
# 2026-02-12 09:22:37.362 | INFO     | data_juicer.core.executor.default_executor:147 - Loading dataset from dataset builder...
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/json/json.py "HTTP/1.1 200 OK"
# 2026-02-12 09:22:37.581 | INFO     | data_juicer.format.formatter:174 - Unifying the input dataset formats...
# 2026-02-12 09:22:37.581 | INFO     | data_juicer.format.formatter:191 - There are 3 sample(s) in the original dataset.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Filter (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 14.68 examples/s]
# 2026-02-12 09:22:37.796 | INFO     | data_juicer.format.formatter:203 - 3 samples left after filtering empty text.
# 2026-02-12 09:22:37.799 | INFO     | data_juicer.core.executor.default_executor:153 - Preparing process operators...
# 2026-02-12 09:22:37.799 | INFO     | data_juicer.core.executor.default_executor:180 - Processing data...
# 2026-02-12 09:22:37.844 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Adding new column for stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 15.60 examples/s]
# 2026-02-12 09:22:38.053 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_compute_stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 13.62 examples/s]
# 2026-02-12 09:22:38.294 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_process (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 13.18 examples/s]
# 2026-02-12 09:22:38.899 | INFO     | data_juicer.core.data.dj_dataset:310 - [1/2] OP [text_length_filter] Done in 1.099s. Left 2 samples.
# 2026-02-12 09:22:38.944 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[words_num_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 2. Reducing num_proc to 2 for dataset of size 2.
# WARNING:datasets.arrow_dataset:num_proc must be <= 2. Reducing num_proc to 2 for dataset of size 2.
# words_num_filter_compute_stats (num_proc=2): 100%|##########| 2/2 [00:00<00:00,  9.76 examples/s]
# 2026-02-12 09:22:39.176 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[words_num_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 2. Reducing num_proc to 2 for dataset of size 2.
# WARNING:datasets.arrow_dataset:num_proc must be <= 2. Reducing num_proc to 2 for dataset of size 2.
# words_num_filter_process (num_proc=2): 100%|##########| 2/2 [00:00<00:00, 10.36 examples/s]
# 2026-02-12 09:22:39.497 | INFO     | data_juicer.core.data.dj_dataset:310 - [2/2] OP [words_num_filter] Done in 0.598s. Left 1 samples.
# 2026-02-12 09:22:41.045 | INFO     | data_juicer.utils.logger_utils:258 - Processing finished with:
# Warnings: 1
# Errors: 0
#
# Error/Warning details can be found in the log file [/workspaces/data-juicer-hub/outputs/log/export_multi_field_processed.jsonl_time_20260212092237.txt] and its related log files.
# 2026-02-12 09:22:41.046 | INFO     | data_juicer.core.executor.default_executor:192 - All OPs are done in 3.247s.
# 2026-02-12 09:22:41.046 | INFO     | data_juicer.core.executor.default_executor:196 - Exporting dataset to disk...
# 2026-02-12 09:22:41.046 | INFO     | data_juicer.core.exporter:154 - Exporting computed stats into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 779.32ba/s]
# 2026-02-12 09:22:41.054 | INFO     | data_juicer.core.exporter:190 - Export dataset into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 1253.15ba/s]
# 2026-02-12 09:22:41.056 | INFO     | data_juicer.tools.process_data:15 - Running executor took 3.69 seconds

# %%
# Check results
with open('./outputs/multi_field_processed.jsonl', 'r') as f:
    for line in f:
        print(json.loads(line))
# Out:
# {'title': 'Introduction to ML', 'text': 'Machine learning is a subset of AI that enables systems to learn from data.'}

# %% [markdown]
# ### Multimodal Field Mapping
#
# Similarly for images, audio, and video:
#
# ```yaml
# # Default field names
# image_key: 'images'
# audio_key: 'audios'
# video_key: 'videos'
#
# # Custom mapping:
# image_key: 'img_paths'   # Your field is called 'img_paths'
# ```

# %% [markdown]
# ---
#
# ## More Data Loading Options

# %% [markdown]
# ### Loading Multiple Files from a Directory

# %%
# Create a directory with multiple text files
os.makedirs('./data/multiple_json', exist_ok=True)

multiple_json = [
    ("intro.json", "Machine learning is a powerful technology that enables computers to learn from data."),
    ("deep_learning.json", "Deep learning is a subset of machine learning using neural networks."),
    ("short.json", "Hi.")
]

for filename, content in multiple_json:
    data = {"text": content}
    with open(f'./data/multiple_json/{filename}', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

print("✅ Created text files:")
for filename, content in multiple_json:
    print(f"  - {filename}: '{content[:40]}...'" if len(content) > 40 else f"  - {filename}: '{content}'")
# Out:
# ✅ Created text files:
#   - intro.json: 'Machine learning is a powerful technolog...'
#   - deep_learning.json: 'Deep learning is a subset of machine lea...'
#   - short.json: 'Hi.'

# %%
# Load all .txt files from directory
config = """project_name: 'directory_demo'
dataset_path: './data/multiple_json/'

suffixes: ['.json']

export_path: './outputs/json_processed.jsonl'

process:
  - text_length_filter:
      min_len: 20
"""

with open('./configs/directory.yaml', 'w') as f:
    f.write(config)

# !dj-process --config ./configs/directory.yaml
# Out:
# 2026-02-12 09:22:48.044 | INFO     | data_juicer.config.config:695 - dataset_path config is set and a valid local path
# 2026-02-12 09:22:48.068 | INFO     | data_juicer.config.config:1012 - Back up the input config file [/workspaces/data-juicer-hub/configs/directory.yaml] into the work_dir [/workspaces/data-juicer-hub/outputs]
# 2026-02-12 09:22:48.073 | INFO     | data_juicer.config.config:1033 - Configuration table:
# ╒══════════════════════════╤═══════════════════════════════════════════════════════════════════════════════╕
# │ key                      │ values                                                                        │
# ╞══════════════════════════╪═══════════════════════════════════════════════════════════════════════════════╡
# │ config                   │ [Path_fr(./configs/directory.yaml, cwd=/workspaces/data-juicer-hub)]          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto                     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_num                 │ 1000                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ hpo_config               │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_algo          │ 'uniform'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ data_probe_ratio         │ 1.0                                                                           │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ project_name             │ 'directory_demo'                                                              │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ executor_type            │ 'default'                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset_path             │ '/workspaces/data-juicer-hub/data/multiple_json'                              │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ dataset                  │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ generated_dataset_config │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ validators               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ work_dir                 │ '/workspaces/data-juicer-hub/outputs'                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_path              │ '/workspaces/data-juicer-hub/outputs/json_processed.jsonl'                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_type              │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_shard_size        │ 0                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_in_parallel       │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_extra_args        │ {}                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_aws_credentials   │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_stats_in_res_ds     │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ keep_hashes_in_res_ds    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ np                       │ 4                                                                             │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ text_keys                │ 'text'                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_key                │ 'images'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_bytes_key          │ 'image_bytes'                                                                 │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ image_special_token      │ '<__dj__image>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_key                │ 'audios'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ audio_special_token      │ '<__dj__audio>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_key                │ 'videos'                                                                      │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ video_special_token      │ '<__dj__video>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ eoc_special_token        │ '<|__dj__eoc|>'                                                               │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ suffixes                 │ ['.json']                                                                     │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ turbo                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ skip_op_error            │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_cache                │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ds_cache_dir             │ '/home/vscode/.cache/huggingface/datasets'                                    │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ cache_compress           │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_monitor             │ True                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ use_checkpoint           │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ temp_dir                 │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_tracer              │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_trace         │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_num                │ 10                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ trace_keys               │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ open_insight_mining      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_list_to_mine          │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ op_fusion                │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ fusion_strategy          │ 'probe'                                                                       │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ adaptive_batch_size      │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ process                  │ [{'text_length_filter': {'accelerator': None,                                 │
# │                          │                          'audio_key': 'audios',                               │
# │                          │                          'auto_op_parallelism': True,                         │
# │                          │                          'batch_mode': None,                                  │
# │                          │                          'cpu_required': None,                                │
# │                          │                          'gpu_required': None,                                │
# │                          │                          'history_key': 'history',                            │
# │                          │                          'image_bytes_key': 'image_bytes',                    │
# │                          │                          'image_key': 'images',                               │
# │                          │                          'index_key': None,                                   │
# │                          │                          'instruction_key': 'instruction',                    │
# │                          │                          'max_closed_interval': True,                         │
# │                          │                          'max_len': 9223372036854775807,                      │
# │                          │                          'mem_required': None,                                │
# │                          │                          'memory': None,                                      │
# │                          │                          'min_closed_interval': True,                         │
# │                          │                          'min_len': 20,                                       │
# │                          │                          'num_cpus': None,                                    │
# │                          │                          'num_gpus': None,                                    │
# │                          │                          'num_proc': 4,                                       │
# │                          │                          'prompt_key': 'prompt',                              │
# │                          │                          'query_key': 'query',                                │
# │                          │                          'ray_execution_mode': None,                          │
# │                          │                          'response_key': 'response',                          │
# │                          │                          'reversed_range': False,                             │
# │                          │                          'runtime_env': None,                                 │
# │                          │                          'skip_op_error': True,                               │
# │                          │                          'stats_export_path': None,                           │
# │                          │                          'system_key': 'system',                              │
# │                          │                          'text_key': 'text',                                  │
# │                          │                          'turbo': False,                                      │
# │                          │                          'video_key': 'videos',                               │
# │                          │                          'work_dir': '/workspaces/data-juicer-hub/outputs'}}] │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ percentiles              │ []                                                                            │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ export_original_dataset  │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ save_stats_in_one_file   │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ ray_address              │ 'auto'                                                                        │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ custom_operator_paths    │ None                                                                          │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ debug                    │ False                                                                         │
# ├──────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ auto_op_parallelism      │ True                                                                          │
# ╘══════════════════════════╧═══════════════════════════════════════════════════════════════════════════════╛
# 2026-02-12 09:22:48.074 | INFO     | data_juicer.tools.process_data:15 - Loading configuration took 0.30 seconds
# 2026-02-12 09:22:48.075 | WARNING  | data_juicer.utils.resource_utils:44 - Command nvidia-smi is not found. There might be no GPUs on this machine.
# 2026-02-12 09:22:48.077 | INFO     | data_juicer.core.executor.default_executor:54 - Using cache compression method: [None]
# 2026-02-12 09:22:48.077 | INFO     | data_juicer.core.executor.default_executor:58 - Setting up dataset builder...
# 2026-02-12 09:22:48.077 | INFO     | data_juicer.core.data.dataset_builder:48 - found dataset_path setting: /workspaces/data-juicer-hub/data/multiple_json
# 2026-02-12 09:22:48.078 | INFO     | data_juicer.core.data.load_strategy:84 - Getting strategy class for exec: default, data_type: local, data_source: None
# 2026-02-12 09:22:48.078 | INFO     | data_juicer.core.executor.default_executor:74 - Preparing exporter...
# 2026-02-12 09:22:48.078 | INFO     | data_juicer.tools.process_data:15 - Initializing executor took 0.00 seconds
# 2026-02-12 09:22:48.078 | INFO     | data_juicer.core.executor.default_executor:147 - Loading dataset from dataset builder...
# INFO:httpx:HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/json/json.py "HTTP/1.1 200 OK"
# Setting num_proc from 4 to 3 for the json split as it only contains 3 shards.
# WARNING:datasets.builder:Setting num_proc from 4 to 3 for the json split as it only contains 3 shards.
# Generating json split: 3 examples [00:00, 17.40 examples/s]
# 2026-02-12 09:22:48.639 | INFO     | data_juicer.format.formatter:174 - Unifying the input dataset formats...
# 2026-02-12 09:22:48.640 | INFO     | data_juicer.format.formatter:191 - There are 3 sample(s) in the original dataset.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Filter (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 15.39 examples/s]
# 2026-02-12 09:22:48.847 | INFO     | data_juicer.format.formatter:203 - 3 samples left after filtering empty text.
# 2026-02-12 09:22:48.849 | INFO     | data_juicer.core.executor.default_executor:153 - Preparing process operators...
# 2026-02-12 09:22:48.850 | INFO     | data_juicer.core.executor.default_executor:180 - Processing data...
# 2026-02-12 09:22:48.891 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Adding new column for stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 15.41 examples/s]
# 2026-02-12 09:22:49.102 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_compute_stats (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 13.60 examples/s]
# 2026-02-12 09:22:49.344 | INFO     | data_juicer.utils.process_utils:161 - Set the auto `num_proc` to 4 of Op[text_length_filter] based on the required memory: NoneGB and required cpu: 1.
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# WARNING:datasets.arrow_dataset:num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# text_length_filter_process (num_proc=3): 100%|##########| 3/3 [00:00<00:00, 13.15 examples/s]
# 2026-02-12 09:22:49.946 | INFO     | data_juicer.core.data.dj_dataset:310 - [1/1] OP [text_length_filter] Done in 1.096s. Left 2 samples.
# 2026-02-12 09:22:50.706 | INFO     | data_juicer.utils.logger_utils:258 - Processing finished with:
# Warnings: 1
# Errors: 0
#
# Error/Warning details can be found in the log file [/workspaces/data-juicer-hub/outputs/log/export_json_processed.jsonl_time_20260212092248.txt] and its related log files.
# 2026-02-12 09:22:50.706 | INFO     | data_juicer.core.executor.default_executor:192 - All OPs are done in 1.857s.
# 2026-02-12 09:22:50.707 | INFO     | data_juicer.core.executor.default_executor:196 - Exporting dataset to disk...
# 2026-02-12 09:22:50.707 | INFO     | data_juicer.core.exporter:154 - Exporting computed stats into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 731.61ba/s]
# 2026-02-12 09:22:50.715 | INFO     | data_juicer.core.exporter:190 - Export dataset into a single file...
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 1461.43ba/s]
# 2026-02-12 09:22:50.717 | INFO     | data_juicer.tools.process_data:15 - Running executor took 2.64 seconds

# %%
# Check results - "Hi." should be filtered out
print("Processed output (text files with >= 20 chars):")
with open('./outputs/json_processed.jsonl', 'r') as f:
    for line in f:
        data = json.loads(line)
        print(f"  - {data['text'][:60]}..." if len(data['text']) > 60 else f"  - {data['text']}")
# Out:
# Processed output (text files with >= 20 chars):
#   - Machine learning is a powerful technology that enables compu...
#   - Deep learning is a subset of machine learning using neural n...

# %% [markdown]
# ### HuggingFace Hub
#
# Load datasets directly from HuggingFace Hub:
#
# ```yaml
# dataset:
#   configs:
#     - type: 'remote'
#       source: 'huggingface'
#       path: "HuggingFaceFW/fineweb"
#       name: "CC-MAIN-2024-10"
#       split: "train"
#       limit: 1000
# ```
#
#
# ### Cloud Storage (S3)
#
# Load data from S3-compatible storage:
#
# ```yaml
# # Load all JSON files from an S3 directory
# dataset:
#   path: s3://my-bucket/data/json-files/
#   format: json  # Must specify format for directory paths
#   aws_access_key_id: xxx
#   aws_secret_access_key: xxx
#
# # Load all Parquet files from an S3 directory
# dataset:
#   path: s3://my-bucket/data/parquet-files/
#   format: parquet
#   aws_access_key_id: xxx
#   aws_secret_access_key: xxx
# ```
#
# For more data loading configurations, please refer to [Dataset Configuration](https://datajuicer.github.io/data-juicer/en/main/docs/DatasetCfg.html).

# %% [markdown]
# ---
#
# ## Format Compatibility Quick Reference
#
# | Your Data Format | Can Use Directly? | Action Needed |
# |------------------|-------------------|---------------|
# | JSONL with `text` field | ✅ Yes | None |
# | JSONL with other field names | ✅ Yes | Set `text_keys: 'your_field'` |
# | Parquet / CSV / TSV | ✅ Yes | Set `text_keys` if needed |
# | Plain text files (.txt, .md) | ✅ Yes | Each file → one sample |
# | PDF / DOCX | ✅ Yes | Text auto-extracted |
# | ShareGPT format | ❌ Convert first | Use [`llama_factory_sharegpt_to_dj.py`](https://github.com/datajuicer/data-juicer/blob/main/tools/fmt_conversion/post_tuning_dialog/source_format_to_data_juicer_format/llama_factory_sharegpt_to_dj.py) [`ms_swift_sharegpt_to_dj.py`](https://github.com/datajuicer/data-juicer/blob/main/tools/fmt_conversion/post_tuning_dialog/source_format_to_data_juicer_format/ms_swift_sharegpt_to_dj.py)|
# | Alpaca format | ❌ Convert first | Use [`alpaca_to_dj.py`](https://github.com/datajuicer/data-juicer/blob/main/tools/fmt_conversion/post_tuning_dialog/source_format_to_data_juicer_format/alpaca_to_dj.py) |
# | Messages format (OpenAI-style) | ❌ Convert first | Use [`messages_to_dj.py`](https://github.com/datajuicer/data-juicer/blob/main/tools/fmt_conversion/post_tuning_dialog/source_format_to_data_juicer_format/messages_to_dj.py) |
# | LLaVA (image-text) | ❌ Convert first | Use [`llava_to_dj.py`](https://github.com/datajuicer/data-juicer/blob/main/tools/fmt_conversion/multimodal/source_format_to_data_juicer_format/llava_to_dj.py) |

# %% [markdown]
# ---
#
# ## Related Tools
#
# Data-Juicer provides additional tools for data preparation:
#
# | Tool Category | Description | Documentation | Notebook |
# |---------------|-------------|---------------|-----------|
# | **Format Conversion** | Convert between formats (ShareGPT, Alpaca, LLaVA, etc.) | [📖 post_tuning_dialog](https://datajuicer.github.io/data-juicer/en/main/tools/fmt_conversion/post_tuning_dialog/README.html) [📖 Multimodal](https://datajuicer.github.io/data-juicer/en/main/tools/fmt_conversion/multimodal/README.html) | [Chapter 9: Multimodal Data Processing](./09_Multimodal_Data_Processing.ipynb) |
# | **Preprocessing** | Prepare raw data before processing | [📖 preprocess](https://datajuicer.github.io/data-juicer/en/main/tools/preprocess/README.html) | [Chapter 8: Preprocessing](./08_Preprocessing.ipynb) |
# | **Postprocessing** | Transform processed data for downstream tasks | [📖 postprocess](https://datajuicer.github.io/data-juicer/en/main/tools/postprocess/README.html) | \ |
#
# These tools are located in `tools/` directory of the Data-Juicer repository.

# %% [markdown]
# ---
#
# ## Further Reading
#
# - 📖 [Dataset Configuration](https://datajuicer.github.io/data-juicer/en/main/docs/DatasetCfg.html)
# - 📖 [Configuration Reference](https://github.com/datajuicer/data-juicer/blob/main/data_juicer/config/config_all.yaml)
# - 📖 [Format Conversion Documentation](https://datajuicer.github.io/data-juicer/en/main/tools/fmt_conversion/README.html)
